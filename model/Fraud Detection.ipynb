# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Fraud.csv')
data
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %% [markdown]
# ### Splitting streaming and training data

# %%
data_for_streaming = data.iloc[5000000:,:]
data_for_ml = data.drop(data_for_streaming.index)

# %%
data_for_ml
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815       170136.0
# 1           1   PAYMENT     1864.28  C1666544295        21249.0
# 2           1  TRANSFER      181.00  C1305486145          181.0
# 3           1  CASH_OUT      181.00   C840083671          181.0
# 4           1   PAYMENT    11668.14  C2048537720        41554.0
# ...       ...       ...         ...          ...            ...
# 4999995   353  TRANSFER  1333061.31  C1540600781            0.0
# 4999996   353  TRANSFER   616382.17   C517196719            0.0
# 4999997   353  TRANSFER  5451700.18  C1537896699            0.0
# 4999998   353  TRANSFER   436886.88  C1190021029            0.0
# 4999999   353   CASH_IN    64178.86    C15059310       404724.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
data_for_streaming
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 5000000   353  TRANSFER   238111.39     C7070830       25910.00
# 5000001   353   PAYMENT     7229.34   C147747120           0.00
# 5000002   353  TRANSFER  1795126.66   C313117857       20936.00
# 5000003   353  TRANSFER  2957345.11  C1295913486        2428.00
# 5000004   353   PAYMENT    43592.35   C906149224         465.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 5000000             0.0   C282676377      2954913.86      3193025.25        0
# ...

# %% [markdown]
# #### Getting streaming data

# %%
data_for_streaming.to_csv("C:/Users/ahmad/Downloads/Real-Time-Fraud-Detection-in-Banking-Transactions/kafka/streaming_data.csv", index=False)

# %% [markdown]
# ## Training the Fraud Detection ML
